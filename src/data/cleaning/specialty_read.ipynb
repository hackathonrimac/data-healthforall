# %%
import pandas as pd

# %%
specialty_data = pd.read_csv('ESPECIALIDAD_CLEAN.csv')
specialty_data.head()
# Out:
#    id                             nombre  \
# 0   1                     Anestesiología
# 1   2                         Angiología
# 2   3       Administración De Hospitales
# 3   4                Anatomía Patológica
# 4   7  Cirugía Torácica Y Cardiovascular
#
#                                          descripcion
# 0  Especialidad médica que se encarga del manejo ...
# 1  Especialidad médica que estudia y trata las en...
# 2  Especialidad en la gestión y administración ef...
# 3  Especialidad médica que estudia las alteracion...
# 4  Especialidad quirúrgica que trata las enfermed...
